# %% [markdown]
# # Problem 2: Prepare state |01>+|10> using analytic gradients

# %% [markdown]
# In this text, we will prepare the state |01>+|10> using 1) Haddamart gate, 2) using rotation operators and 3) using analytic gradient optimisation technique in rotation function angles.
#
# Note: I have prepared a writup to create the state using Haddamard gate and analyse the quantum state using different number of simulations. The parts to use RX and RY gates and analytic gradient optimisation are incomplete at the moment.

# %% [markdown]
# ### Installing necessary packages

# %% [markdown]
# Before we begin, you will need to install some prerequisites into your environment.

# %%
# !pip install -U -r tools/requirements.txt

from IPython.display import clear_output
clear_output()

# %%
from qiskit.quantum_info import Operator
from qiskit import QuantumCircuit
import numpy as np

# %% [markdown]
# ### 1) Creation of entangled states using Haddamard gate

# %%
def target_state1(n, indices_of_marked_elements):
    
    # Create a quantum circuit on 2 qubits
    qc = QuantumCircuit(2, 2)
    
    # step 1: apply Hadamard gates on first gate qubits
    qc.h(0)
    
    # step 2: cnot gate on the second gate
    qc.cx(0,1)
    qc.x(1)
        
    # step 3: measure all qubits
    qc.measure(range(2), range(2))
  
    return qc

mycircuit = target_state1(6, [1, 42])
mycircuit.draw(output='text')
# Out:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├───
#      └───┘┌─┴─┐┌───┐└╥┘┌─┐
# q_1: ─────┤ X ├┤ X ├─╫─┤M├
#           └───┘└───┘ ║ └╥┘
# c_0: ════════════════╩══╬═
#                         ║
# c_1: ═══════════════════╩═

# %%
from qiskit import Aer, execute
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %% [markdown]
# The above graph shows that the resulting sate is a superposition of states |01> and |10> where |01> and |10> occur with the same probability. We can look at the probability distribution using different number of simulation shots as follows:

# %%
from qiskit import Aer, execute
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1).result().get_counts(mycircuit)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
from qiskit import Aer, execute
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=10).result().get_counts(mycircuit)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
from qiskit import Aer, execute
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=100).result().get_counts(mycircuit)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
from qiskit import Aer, execute
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
from qiskit import Aer, execute
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=10000).result().get_counts(mycircuit)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %% [markdown]
# The more shots you take, the close the probability appeats to 0.500. This is because more simlations improve our visualisation of the entangled state. With more measurements, we get a more and more precise picture of the state stored in the two qubits.

# %% [markdown]
# ### 2) Creation of entangled state using rotator operators

# %% [markdown]
# Incomplete

# %% [markdown]
# ### 3) Creation of entangled state using analytic gradient optimisation technique

# %%
from qiskit.aqua.components.optimizers import AQGD
def target_state2(n, indices_of_marked_elements):
    
    # Create a quantum circuit on 2 qubits
    qc = QuantumCircuit(2, 2)
    
    # optimisation to create + state
    AQGD.print_options()
    
    # reach target state using cnots (use rotation for x gate on 1)
    
        
    # step 3: measure all qubits
    qc.measure(range(2), range(2))
  
    return qc

mycircuit = target_state2(6, [1, 42])
mycircuit.draw(output='text')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c0a12083ea3d> in <module>
#      16     return qc
#      17
# ---> 18 mycircuit = target_state2(6, [1, 42])
#      19 mycircuit.draw(output='text')
#
# <ipython-input-11-c0a12083ea3d> in target_state2(n, indices_of_marked_elements)
#       6
#       7     # optimisation to create + state
# ----> 8     AQGD.print_options()
#       9
#      10     # reach target state using cnots (use rotation for x gate on 1)
#
# TypeError: print_options() missing 1 required positional argument: 'self'

# %% [markdown]
# ### Bibliography

# %% [markdown]
# 1. I have used the file "requirements.txt" from Qiskit Global summer school lab excercises to simplify installation of qiskit library functions in Jupyter.
